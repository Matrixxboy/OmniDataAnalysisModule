# %%
print("Deliver pizza!")
print("Deliver pizza!")
print("Deliver pizza!")
print("Deliver pizza!")
print("Deliver pizza!")
# Out:
# Deliver pizza!
# Deliver pizza!
# Deliver pizza!
# Deliver pizza!
# Deliver pizza!

# %%
for i in range(5):
    print(f"{i}_Deliver pizza!  {i}+1")
    # i+1
# Out:
# 0_Deliver pizza!  0+1
# 1_Deliver pizza!  1+1
# 2_Deliver pizza!  2+1
# 3_Deliver pizza!  3+1
# 4_Deliver pizza!  4+1

# %%
# condi print only if i = 2

for i in range(5):
    print(f"i = {i}")
    if (i==2):
        print("Yes i = 2")
# Out:
# i = 0
# i = 1
# i = 2
# Yes i = 2
# i = 3
# i = 4

# %%
for number in range(1, 11):
    print(f"the number is : {number}")
    if number % 2 == 0:
        print(number, "is EVEN 🟢")
    else:
        print(number, "is ODD 🔴")
# Out:
# the number is : 1
# 1 is ODD 🔴
# the number is : 2
# 2 is EVEN 🟢
# the number is : 3
# 3 is ODD 🔴
# the number is : 4
# 4 is EVEN 🟢
# the number is : 5
# 5 is ODD 🔴
# the number is : 6
# 6 is EVEN 🟢
# the number is : 7
# 7 is ODD 🔴
# the number is : 8
# 8 is EVEN 🟢
# the number is : 9
# 9 is ODD 🔴
# the number is : 10
# 10 is EVEN 🟢

# %%
fruits = ["apple", "banana", "cherry","mango"]

for ok in fruits:
    print(ok)


# for ok in range(len(fruits)):
#     print(fruits[ok])
#     # i + 1
# Out:
# apple
# banana
# cherry
# mango

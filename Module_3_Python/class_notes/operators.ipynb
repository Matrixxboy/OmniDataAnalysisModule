# %%
x = 5
print("x = ",5)
# Out:
# x =  5

# %%
x += 5
print("x = ",x)
# Out:
# x =  10

# %%
x -= 5
print("x = ",x)
# Out:
# x =  5

# %%
x *= 5
print("x = ",x)
# Out:
# x =  25

# %%
x //= 5
print("x = ",x)
# Out:
# x =  0

# %%
x **=5
print("x = ",x)
# Out:
# x =  3125

# %%
y=11
y /= 2
print("y = ",y)
# Out:
# y =  5.5

# %%
score = 80

if score >= 90:
    print("Wow")
elif score >= 80:
    print("little Wow")
elif score >=70:
    print("Good")
else:
    print("Not good")
# Out:
# little Wow

# %%
# ── Job Application Filter — Omni Career Hub ──
applicant = {
    "name"     : "Riya Sharma",
    "experience": 5,
    "score"    : 100,
    "projects" : 12,
}

exp_ok  = applicant["experience"] >= 2
scr_ok  = applicant["score"] >= 75
proj_ok = applicant["projects"] >= 3

print("exp_ok = ",exp_ok)
print("\nscr_ok = ",scr_ok)
print("\nproj_ok = ",proj_ok)

if exp_ok and scr_ok and proj_ok:
    status = "✅ SELECTED — Schedule Interview"
elif exp_ok and scr_ok:
    status = "⏳ WAITLISTED — Needs more projects"
elif scr_ok:
    status = "📋 REVIEW — Good score, low experience"
else:
    status = "❌ REJECTED"

print(f"Applicant : {applicant['name']}")
print(f"Status    : {status}")

print("Party when ?? " , applicant['name'])
# Out:
# exp_ok =  True
#
# scr_ok =  True
#
# proj_ok =  True
# Applicant : Riya Sharma
# Status    : ✅ SELECTED — Schedule Interview
# Party when ??  Riya Sharma

# %%
day = "MON"
match day:
    case "SAT" | "SUN":
        print("Weekend!")
    case "MON"|"TUE"|"WED"|"THU"|"FRI":
        print("Weekday — Work at Omni Career Hub")
    case _:
        print("Invalid day")
# Out:
# Weekday — Work at Omni Career Hub

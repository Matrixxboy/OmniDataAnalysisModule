# %% [markdown]
# # LIST

# %%
# ── Creation & Access ────────────────────────
skills = ["Python","SQL","ML","Power BI","Django"]

# print(skills[0])    
# print(skills[-1])   
# print(skills[1:3])  
# print(len(skills))  

# ── Methods ──────────────────────────────────
# skills.append("FastAPI")
# skills.insert(len(skills), "Statistics")
# print(skills)
# skills.remove("Power BI")
print(skills)
popped = skills.pop()
print(skills)

# print("After ops:", skills)
# print("Popped:", popped)

# skills.sort()
# print("Sorted:", skills)
# Out:
# ['Python', 'SQL', 'ML', 'Power BI', 'Django']
# ['Python', 'SQL', 'ML', 'Power BI']

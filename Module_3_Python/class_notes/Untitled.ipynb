# %%
name = "Utsav Lankapati"
print(f"First Name = {name} !!!")
# Out:
# First Name = Utsav Lankapati !!!

# %%
name = "Utsav"
org = "XYZ"
exp = True

print(f"Hi, I am {name}. I work at {org} and have {exp} years of experience.")
# Out:
# Hi, I am Utsav. I work at XYZ and have True years of experience.

# %%
# multiLine 

multi = """1. 
2. 
3.
"""

print(multi)
print("1. 2. 3.")
# Out:
# 1.
# 2.
# 3.
#
# 1. 2. 3.

# %%
is_student    = False

print("Boolean as Int (True): ", int(True))
print("Boolean as Int (False):", int(False))
# Out:
# Boolean as Int (True):  1
# Boolean as Int (False): 0

# %%
print("\n--- Truthy & Falsy ---")
print("bool(0)    ->", bool(0))      # False
print("bool('')   ->", bool(""))     # False
print("bool([])   ->", bool([]))     # False
print("bool(42)   ->", bool(42))     # True
print("bool('utsav') ->", bool("utsav"))   # True
# Out:
# --- Truthy & Falsy ---
# bool(0)    -> False
# bool('')   -> False
# bool([])   -> False
# bool(42)   -> True
# bool('utsav') -> True

# %%
resume = None
if resume is not None:
    print("\nPlease upload your resume! (Value is None)")
else:
    print("Hired !!!")
# Out:
# Hired !!!

# %%
is_verified   = False  # 0
has_portfolio = True  # 0

profile_ready = is_verified or has_portfolio

print(profile_ready)
# Out:
# True

# %%
listwow=["firstperson","secper","thirdPer"]
print(listwow[-1])
# Out:
# thirdPer
